# %%
# step 1
from model_testing.step_1 import encode_object_columns
from model_testing.step_1 import one_hot_object_columns
from model_testing.step_1 import one_hot_categorical_columns
from model_testing.step_1 import one_hot_all
from model_testing.step_1 import encode_categorical_model
from model_testing.step_1 import one_hot_categorical_model
from model_testing.step_1 import continues_model
from model_testing.step_1 import one_hot_continues_model

# step 2
from model_testing.step_2 import selection_anova_model
from model_testing.step_2 import selection_chi2_model
from model_testing.step_2 import selection_mutual_info_model
from model_testing.step_2 import selection_variance_model
from model_testing.step_2 import selection_decision_tree_model
from model_testing.step_2 import selection_p_correlation

# step 3
from model_testing.step_3 import over_sampling_smote_model
from model_testing.step_3 import over_sampling_random_model
from model_testing.step_3 import over_sampling_adasyn_model
from model_testing.step_3 import over_sampling_svmsmote_model
from model_testing.step_3 import under_sampling_random_model
from model_testing.step_3 import under_sampling_cluster_centroids_model

# Others
import pandas as pd

from plotting.plotting_data import plot_correlation
from cleaning.cleaning_data import read_data
from model_testing.config import DATASET_PATH

# %% [markdown]
# # Loading Dataset

# %%
df = read_data(DATASET_PATH)

df.head()

# %%
df.info()

# %%
plot_correlation(df)

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Step 1

# %%
print("\nEncode Object Columns")
encode_object_columns()
# Out:
# Encode Object Columns
# Model 1 | training_accuracy : 1.0 | validation_accuracy : 0.8987466207913493
# Model 2 | training_accuracy : 0.8791913811887181 | validation_accuracy : 0.8783484885721308
# Model 3 | training_accuracy : 0.8475971432030021 | validation_accuracy : 0.845908085524699
# Model 4 | training_accuracy : 1.0 | validation_accuracy : 0.8640943720815926
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3436
#            1       0.73      0.56      0.63       633
#
#     accuracy                           0.90      4069
#    macro avg       0.83      0.76      0.79      4069
# weighted avg       0.89      0.90      0.89      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      3436
#            1       0.74      0.34      0.46       633
#
#     accuracy                           0.88      4069
#    macro avg       0.81      0.66      0.70      4069
# weighted avg       0.87      0.88      0.86      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      3436
#            1       0.88      0.01      0.02       633
#
#     accuracy                           0.85      4069
#    macro avg       0.86      0.51      0.47      4069
# weighted avg       0.85      0.85      0.78      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      3436
#            1       0.56      0.55      0.56       633
#
#     accuracy                           0.86      4069
#    macro avg       0.74      0.74      0.74      4069
# weighted avg       0.86      0.86      0.86      4069

# %%
print("\nOne Hot Object Columns")
one_hot_object_columns()
# Out:
# One Hot Object Columns
# Model 1 | training_accuracy : 0.9998789492797482 | validation_accuracy : 0.9002211845662325
# Model 2 | training_accuracy : 0.8828229027962716 | validation_accuracy : 0.8771196854263947
# Model 3 | training_accuracy : 0.8475971432030021 | validation_accuracy : 0.845908085524699
# Model 4 | training_accuracy : 1.0 | validation_accuracy : 0.8621282870484148
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3436
#            1       0.74      0.55      0.63       633
#
#     accuracy                           0.90      4069
#    macro avg       0.83      0.76      0.79      4069
# weighted avg       0.89      0.90      0.89      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      3436
#            1       0.72      0.35      0.47       633
#
#     accuracy                           0.88      4069
#    macro avg       0.80      0.66      0.70      4069
# weighted avg       0.86      0.88      0.86      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      3436
#            1       0.88      0.01      0.02       633
#
#     accuracy                           0.85      4069
#    macro avg       0.86      0.51      0.47      4069
# weighted avg       0.85      0.85      0.78      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      3436
#            1       0.56      0.57      0.56       633
#
#     accuracy                           0.86      4069
#    macro avg       0.74      0.74      0.74      4069
# weighted avg       0.86      0.86      0.86      4069

# %%
print("\nOne Hot Categorical Columns")
one_hot_categorical_columns()
# Out:
# One Hot Categorical Columns
# Model 1 | training_accuracy : 1.0 | validation_accuracy : 0.8901449987711969
# Model 2 | training_accuracy : 0.8828229027962716 | validation_accuracy : 0.8840009830425166
# Model 3 | training_accuracy : 0.8475971432030021 | validation_accuracy : 0.8461538461538461
# Model 4 | training_accuracy : 1.0 | validation_accuracy : 0.8690095846645367
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      3436
#            1       0.78      0.41      0.54       633
#
#     accuracy                           0.89      4069
#    macro avg       0.84      0.69      0.74      4069
# weighted avg       0.88      0.89      0.88      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.93      3436
#            1       0.75      0.38      0.51       633
#
#     accuracy                           0.88      4069
#    macro avg       0.82      0.68      0.72      4069
# weighted avg       0.87      0.88      0.87      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      3436
#            1       1.00      0.01      0.02       633
#
#     accuracy                           0.85      4069
#    macro avg       0.92      0.51      0.47      4069
# weighted avg       0.87      0.85      0.78      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92      3436
#            1       0.58      0.55      0.56       633
#
#     accuracy                           0.87      4069
#    macro avg       0.75      0.74      0.74      4069
# weighted avg       0.87      0.87      0.87      4069

# %%
print("\nEncode Categorical Model")
encode_categorical_model()
# Out:
# Encode Categorical Model
# Model 1 | training_accuracy : 0.9984263406367268 | validation_accuracy : 0.8341115753256328
# Model 2 | training_accuracy : 0.8446919259169592 | validation_accuracy : 0.8419759154583436
# Model 3 | training_accuracy : 0.8456603316789735 | validation_accuracy : 0.8444335217498157
# Model 4 | training_accuracy : 0.9984263406367268 | validation_accuracy : 0.7586630621774392
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      3436
#            1       0.37      0.10      0.15       633
#
#     accuracy                           0.83      4069
#    macro avg       0.61      0.53      0.53      4069
# weighted avg       0.78      0.83      0.79      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91      3436
#            1       0.34      0.02      0.03       633
#
#     accuracy                           0.84      4069
#    macro avg       0.59      0.51      0.47      4069
# weighted avg       0.77      0.84      0.78      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.92      3436
#            1       0.00      0.00      0.00       633
#
#     accuracy                           0.84      4069
#    macro avg       0.42      0.50      0.46      4069
# weighted avg       0.71      0.84      0.77      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      3436
#            1       0.23      0.24      0.24       633
#
#     accuracy                           0.76      4069
#    macro avg       0.55      0.55      0.55      4069
# weighted avg       0.76      0.76      0.76      4069

# %%
print("\nOne Hot Categorical Model")
one_hot_categorical_model()
# Out:
# One Hot Categorical Model
# Model 1 | training_accuracy : 0.9984263406367268 | validation_accuracy : 0.8417301548291963
# Model 2 | training_accuracy : 0.849897106887786 | validation_accuracy : 0.8427131973457852
# Model 3 | training_accuracy : 0.8457813823992253 | validation_accuracy : 0.8444335217498157
# Model 4 | training_accuracy : 0.9984263406367268 | validation_accuracy : 0.7797984762840993
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91      3436
#            1       0.39      0.03      0.06       633
#
#     accuracy                           0.84      4069
#    macro avg       0.62      0.51      0.49      4069
# weighted avg       0.78      0.84      0.78      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91      3436
#            1       0.44      0.04      0.08       633
#
#     accuracy                           0.84      4069
#    macro avg       0.65      0.52      0.50      4069
# weighted avg       0.79      0.84      0.78      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.92      3436
#            1       0.00      0.00      0.00       633
#
#     accuracy                           0.84      4069
#    macro avg       0.42      0.50      0.46      4069
# weighted avg       0.71      0.84      0.77      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87      3436
#            1       0.25      0.20      0.22       633
#
#     accuracy                           0.78      4069
#    macro avg       0.55      0.54      0.55      4069
# weighted avg       0.76      0.78      0.77      4069

# %%
print("\nContinues Model")
continues_model()
# Out:
# Continues Model
# Model 1 | training_accuracy : 0.9996368478392447 | validation_accuracy : 0.8928483656918161
# Model 2 | training_accuracy : 0.8816123955937538 | validation_accuracy : 0.8803145736053084
# Model 3 | training_accuracy : 0.8475971432030021 | validation_accuracy : 0.845908085524699
# Model 4 | training_accuracy : 0.9997578985594965 | validation_accuracy : 0.8545097075448513
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3436
#            1       0.70      0.55      0.61       633
#
#     accuracy                           0.89      4069
#    macro avg       0.81      0.75      0.78      4069
# weighted avg       0.89      0.89      0.89      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      3436
#            1       0.75      0.34      0.47       633
#
#     accuracy                           0.88      4069
#    macro avg       0.82      0.66      0.70      4069
# weighted avg       0.87      0.88      0.86      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      3436
#            1       0.88      0.01      0.02       633
#
#     accuracy                           0.85      4069
#    macro avg       0.86      0.51      0.47      4069
# weighted avg       0.85      0.85      0.78      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91      3436
#            1       0.53      0.54      0.54       633
#
#     accuracy                           0.85      4069
#    macro avg       0.72      0.73      0.73      4069
# weighted avg       0.86      0.85      0.86      4069

# %%
# print("\nOne Hot All")
# one_hot_all()

# %%
# print("\nOne Hot Continues Model")
# one_hot_continues_model()

# %% [markdown]
# ## Step 2

# %%
print("\nSelection ANOVA Model")
selection_anova_model()
# Out:
# Selection ANOVA Model
# Model 1 | training_accuracy : 0.9997578985594965 | validation_accuracy : 0.8918653231752274
# Model 2 | training_accuracy : 0.8874228301658394 | validation_accuracy : 0.8847382649299582
# Model 3 | training_accuracy : 0.8475971432030021 | validation_accuracy : 0.8461538461538461
# Model 4 | training_accuracy : 0.9997578985594965 | validation_accuracy : 0.8596706807569428
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3436
#            1       0.70      0.53      0.60       633
#
#     accuracy                           0.89      4069
#    macro avg       0.81      0.74      0.77      4069
# weighted avg       0.88      0.89      0.89      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.93      3436
#            1       0.76      0.38      0.50       633
#
#     accuracy                           0.88      4069
#    macro avg       0.83      0.68      0.72      4069
# weighted avg       0.87      0.88      0.87      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      3436
#            1       1.00      0.01      0.02       633
#
#     accuracy                           0.85      4069
#    macro avg       0.92      0.51      0.47      4069
# weighted avg       0.87      0.85      0.78      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      3436
#            1       0.55      0.54      0.55       633
#
#     accuracy                           0.86      4069
#    macro avg       0.73      0.73      0.73      4069
# weighted avg       0.86      0.86      0.86      4069

# %%
print("\nSelection Chi2 Model")
selection_chi2_model()
# Out:
# Selection Chi2 Model
# Model 1 | training_accuracy : 0.9997578985594965 | validation_accuracy : 0.8906365200294912
# Model 2 | training_accuracy : 0.8854860186418109 | validation_accuracy : 0.8830179405259277
# Model 3 | training_accuracy : 0.8475971432030021 | validation_accuracy : 0.845908085524699
# Model 4 | training_accuracy : 0.9998789492797482 | validation_accuracy : 0.857704595723765
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94      3436
#            1       0.69      0.55      0.61       633
#
#     accuracy                           0.89      4069
#    macro avg       0.80      0.75      0.77      4069
# weighted avg       0.88      0.89      0.89      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      3436
#            1       0.77      0.35      0.48       633
#
#     accuracy                           0.88      4069
#    macro avg       0.83      0.67      0.71      4069
# weighted avg       0.87      0.88      0.86      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      3436
#            1       0.88      0.01      0.02       633
#
#     accuracy                           0.85      4069
#    macro avg       0.86      0.51      0.47      4069
# weighted avg       0.85      0.85      0.78      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.92      3436
#            1       0.54      0.54      0.54       633
#
#     accuracy                           0.86      4069
#    macro avg       0.73      0.73      0.73      4069
# weighted avg       0.86      0.86      0.86      4069

# %%
print("\nSelection Mutual Info Model")
selection_mutual_info_model()
# Out:
# Selection Mutual Info Model
# Model 1 | training_accuracy : 1.0 | validation_accuracy : 0.8982550995330548
# Model 2 | training_accuracy : 0.8812492434329984 | validation_accuracy : 0.8788400098304252
# Model 3 | training_accuracy : 0.8475971432030021 | validation_accuracy : 0.8461538461538461
# Model 4 | training_accuracy : 1.0 | validation_accuracy : 0.8545097075448513
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3436
#            1       0.72      0.57      0.63       633
#
#     accuracy                           0.90      4069
#    macro avg       0.82      0.76      0.79      4069
# weighted avg       0.89      0.90      0.89      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      3436
#            1       0.74      0.34      0.47       633
#
#     accuracy                           0.88      4069
#    macro avg       0.82      0.66      0.70      4069
# weighted avg       0.87      0.88      0.86      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      3436
#            1       1.00      0.01      0.02       633
#
#     accuracy                           0.85      4069
#    macro avg       0.92      0.51      0.47      4069
# weighted avg       0.87      0.85      0.78      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91      3436
#            1       0.53      0.52      0.53       633
#
#     accuracy                           0.85      4069
#    macro avg       0.72      0.72      0.72      4069
# weighted avg       0.85      0.85      0.85      4069

# %%
print("\nSelection Variance Model")
selection_variance_model()
# Out:
# Selection Variance Model
# Model 1 | training_accuracy : 1.0 | validation_accuracy : 0.8980093389039076
# Model 2 | training_accuracy : 0.8791913811887181 | validation_accuracy : 0.8783484885721308
# Model 3 | training_accuracy : 0.8475971432030021 | validation_accuracy : 0.845908085524699
# Model 4 | training_accuracy : 1.0 | validation_accuracy : 0.8608994839026788
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3436
#            1       0.72      0.56      0.63       633
#
#     accuracy                           0.90      4069
#    macro avg       0.82      0.76      0.79      4069
# weighted avg       0.89      0.90      0.89      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      3436
#            1       0.74      0.34      0.46       633
#
#     accuracy                           0.88      4069
#    macro avg       0.81      0.66      0.70      4069
# weighted avg       0.87      0.88      0.86      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      3436
#            1       0.88      0.01      0.02       633
#
#     accuracy                           0.85      4069
#    macro avg       0.86      0.51      0.47      4069
# weighted avg       0.85      0.85      0.78      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      3436
#            1       0.55      0.54      0.55       633
#
#     accuracy                           0.86      4069
#    macro avg       0.74      0.73      0.73      4069
# weighted avg       0.86      0.86      0.86      4069

# %%
print("\nSelection Decision Tree Model")
selection_decision_tree_model()
# Out:
# Selection Decision Tree Model
# Model 1 | training_accuracy : 0.9998789492797482 | validation_accuracy : 0.8980093389039076
# Model 2 | training_accuracy : 0.8801597869507324 | validation_accuracy : 0.8766281641681003
# Model 3 | training_accuracy : 0.8475971432030021 | validation_accuracy : 0.845908085524699
# Model 4 | training_accuracy : 0.9998789492797482 | validation_accuracy : 0.8557385106905874
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3436
#            1       0.72      0.57      0.63       633
#
#     accuracy                           0.90      4069
#    macro avg       0.82      0.76      0.79      4069
# weighted avg       0.89      0.90      0.89      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      3436
#            1       0.71      0.35      0.47       633
#
#     accuracy                           0.88      4069
#    macro avg       0.80      0.66      0.70      4069
# weighted avg       0.86      0.88      0.86      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      3436
#            1       0.88      0.01      0.02       633
#
#     accuracy                           0.85      4069
#    macro avg       0.86      0.51      0.47      4069
# weighted avg       0.85      0.85      0.78      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91      3436
#            1       0.54      0.54      0.54       633
#
#     accuracy                           0.86      4069
#    macro avg       0.73      0.73      0.73      4069
# weighted avg       0.86      0.86      0.86      4069

# %%
print("\nSelection P Correlation")
selection_p_correlation()
# Out:
# Selection P Correlation
# Model 1 | training_accuracy : 0.9986684420772304 | validation_accuracy : 0.8820348980093389
# Model 2 | training_accuracy : 0.8823386999152645 | validation_accuracy : 0.8800688129761612
# Model 3 | training_accuracy : 0.8475971432030021 | validation_accuracy : 0.8463996067829934
# Model 4 | training_accuracy : 0.9987894927974822 | validation_accuracy : 0.848365691816171
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93      3436
#            1       0.65      0.52      0.58       633
#
#     accuracy                           0.88      4069
#    macro avg       0.78      0.74      0.76      4069
# weighted avg       0.87      0.88      0.88      4069
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      3436
#            1       0.75      0.34      0.47       633
#
#     accuracy                           0.88      4069
#    macro avg       0.82      0.66      0.70      4069
# weighted avg       0.87      0.88      0.86      4069
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      3436
#            1       1.00      0.01      0.02       633
#
#     accuracy                           0.85      4069
#    macro avg       0.92      0.51      0.47      4069
# weighted avg       0.87      0.85      0.78      4069
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      3436
#            1       0.51      0.53      0.52       633
#
#     accuracy                           0.85      4069
#    macro avg       0.71      0.72      0.71      4069
# weighted avg       0.85      0.85      0.85      4069

# %% [markdown]
# ## Step 3

# %%
print("\nOver Sampling SMOTE Model")
over_sampling_smote_model()
# Out:
# Over Sampling SMOTE Model
# Model 1 | training_accuracy : 1.0 | validation_accuracy : 0.8816088225754135
# Model 2 | training_accuracy : 0.8320771589167093 | validation_accuracy : 0.8725267596496918
# Model 3 | training_accuracy : 0.7309657639243741 | validation_accuracy : 0.7249432371067143
# Model 4 | training_accuracy : 1.0 | validation_accuracy : 0.8462536490431398
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      2594
#            1       0.61      0.73      0.66       489
#
#     accuracy                           0.88      3083
#    macro avg       0.78      0.82      0.79      3083
# weighted avg       0.89      0.88      0.89      3083
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      2594
#            1       0.58      0.70      0.64       489
#
#     accuracy                           0.87      3083
#    macro avg       0.76      0.80      0.78      3083
# weighted avg       0.88      0.87      0.88      3083
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.94      0.72      0.82      2594
#            1       0.33      0.74      0.46       489
#
#     accuracy                           0.72      3083
#    macro avg       0.64      0.73      0.64      3083
# weighted avg       0.84      0.72      0.76      3083
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91      2594
#            1       0.51      0.63      0.56       489
#
#     accuracy                           0.85      3083
#    macro avg       0.72      0.76      0.74      3083
# weighted avg       0.86      0.85      0.85      3083

# %%
print("\nOver Sampling Random Model")
over_sampling_random_model()
# Out:
# Over Sampling Random Model
# Model 1 | training_accuracy : 1.0 | validation_accuracy : 0.8913396042815439
# Model 2 | training_accuracy : 0.811765457332652 | validation_accuracy : 0.8734998378203049
# Model 3 | training_accuracy : 0.7248978027593255 | validation_accuracy : 0.7392150502757054
# Model 4 | training_accuracy : 1.0 | validation_accuracy : 0.859552384041518
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      2594
#            1       0.66      0.65      0.66       489
#
#     accuracy                           0.89      3083
#    macro avg       0.80      0.80      0.80      3083
# weighted avg       0.89      0.89      0.89      3083
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92      2594
#            1       0.58      0.74      0.65       489
#
#     accuracy                           0.87      3083
#    macro avg       0.76      0.82      0.79      3083
# weighted avg       0.89      0.87      0.88      3083
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      2594
#            1       0.35      0.74      0.48       489
#
#     accuracy                           0.74      3083
#    macro avg       0.64      0.74      0.65      3083
# weighted avg       0.85      0.74      0.77      3083
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.92      2594
#            1       0.56      0.53      0.54       489
#
#     accuracy                           0.86      3083
#    macro avg       0.74      0.72      0.73      3083
# weighted avg       0.86      0.86      0.86      3083

# %%
print("\nOver Sampling ADASYN Model")
over_sampling_adasyn_model()
# Out:
# Over Sampling ADASYN Model
# Model 1 | training_accuracy : 1.0 | validation_accuracy : 0.8845280570872527
# Model 2 | training_accuracy : 0.8205621871390065 | validation_accuracy : 0.8644177748945832
# Model 3 | training_accuracy : 0.6939417276344501 | validation_accuracy : 0.6808303600389232
# Model 4 | training_accuracy : 1.0 | validation_accuracy : 0.8381446642880311
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      2594
#            1       0.61      0.74      0.67       489
#
#     accuracy                           0.88      3083
#    macro avg       0.78      0.82      0.80      3083
# weighted avg       0.90      0.88      0.89      3083
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92      2594
#            1       0.55      0.74      0.63       489
#
#     accuracy                           0.86      3083
#    macro avg       0.75      0.81      0.78      3083
# weighted avg       0.89      0.86      0.87      3083
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.94      0.66      0.78      2594
#            1       0.30      0.77      0.43       489
#
#     accuracy                           0.68      3083
#    macro avg       0.62      0.72      0.61      3083
# weighted avg       0.84      0.68      0.72      3083
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90      2594
#            1       0.49      0.63      0.55       489
#
#     accuracy                           0.84      3083
#    macro avg       0.71      0.75      0.73      3083
# weighted avg       0.86      0.84      0.85      3083

# %%
print("\nOver Sampling SVMSMOTE Model")
over_sampling_svmsmote_model()
# Out:
# Over Sampling SVMSMOTE Model
# Model 1 | training_accuracy : 0.9998722534491569 | validation_accuracy : 0.88582549464807
# Model 2 | training_accuracy : 0.8633111905978539 | validation_accuracy : 0.8725267596496918
# Model 3 | training_accuracy : 0.7901762902401636 | validation_accuracy : 0.8066818034382095
# Model 4 | training_accuracy : 1.0 | validation_accuracy : 0.8546869931884528
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      2594
#            1       0.62      0.73      0.67       489
#
#     accuracy                           0.89      3083
#    macro avg       0.78      0.82      0.80      3083
# weighted avg       0.90      0.89      0.89      3083
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92      2594
#            1       0.59      0.66      0.62       489
#
#     accuracy                           0.87      3083
#    macro avg       0.76      0.79      0.77      3083
# weighted avg       0.88      0.87      0.88      3083
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88      2594
#            1       0.42      0.60      0.50       489
#
#     accuracy                           0.81      3083
#    macro avg       0.67      0.72      0.69      3083
# weighted avg       0.84      0.81      0.82      3083
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91      2594
#            1       0.53      0.66      0.59       489
#
#     accuracy                           0.85      3083
#    macro avg       0.73      0.77      0.75      3083
# weighted avg       0.87      0.85      0.86      3083

# %%
print("\nUnder Sampling Random Model")
under_sampling_random_model()
# Out:
# Under Sampling Random Model
# Model 1 | training_accuracy : 1.0 | validation_accuracy : 0.853065196237431
# Model 2 | training_accuracy : 0.8269908386187456 | validation_accuracy : 0.8683100875770353
# Model 3 | training_accuracy : 0.657152924594785 | validation_accuracy : 0.5939020434641583
# Model 4 | training_accuracy : 1.0 | validation_accuracy : 0.807979240999027
#
# Title : Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91      2594
#            1       0.52      0.85      0.65       489
#
#     accuracy                           0.85      3083
#    macro avg       0.75      0.85      0.78      3083
# weighted avg       0.90      0.85      0.87      3083
#
#
# Title : Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92      2594
#            1       0.56      0.76      0.65       489
#
#     accuracy                           0.87      3083
#    macro avg       0.76      0.83      0.78      3083
# weighted avg       0.89      0.87      0.88      3083
#
#
# Title : Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.93      0.56      0.70      2594
#            1       0.25      0.77      0.38       489
#
#     accuracy                           0.59      3083
#    macro avg       0.59      0.66      0.54      3083
# weighted avg       0.82      0.59      0.65      3083
#
#
# Title : Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.96      0.81      0.88      2594
#            1       0.44      0.80      0.57       489
#
#     accuracy                           0.81      3083
#    macro avg       0.70      0.81      0.72      3083
# weighted avg       0.87      0.81      0.83      3083
